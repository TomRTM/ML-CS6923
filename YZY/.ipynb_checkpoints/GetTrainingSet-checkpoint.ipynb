# %%
import tweepy,json
import csv,time
from tweepy import OAuthHandler
from tweepy import Stream
#from shapely.geometry import Polygon
import pandas as pd
import numpy as np


access_token='711280829754957824-C9G1QZ59Ukg8aC7fC71RahXKrkaJwhs'
access_token_secret='SzJw81cTi69Ek9ZFAGgcQCIqpcKsXENxXOcUXYRiuYj1h'
consumer_key='FULJuYkzUUQPGBktEpleo1faG'
consumer_secret='LCeH1iDc0W2X4Qjh7Oiz3fqxqkT2yknk4uIO3zwUHudWcoUydY'
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api=tweepy.API(auth)

# %%
import botornot
consumer_key = 'MZ8fXiLq1KhxO11UwAbjW99cm'
consumer_secret = 'Dn50Md2gWlbVxybHAKgI1Knob71ugiF7Q7gIJClN33M1GYySCj'
access_token = '52647948-xnlwpbETyFNX0JmEcdrsB7FLI42fTimAbyXK1xgOM'
access_secret = 'xiYL3QEpPmNmbR0AhqphvS2s2Tyf0V0FOOcpKRb92d4kL'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)


twitter_app_auth = {
  'consumer_key': 'MZ8fXiLq1KhxO11UwAbjW99cm',
  'consumer_secret': 'Dn50Md2gWlbVxybHAKgI1Knob71ugiF7Q7gIJClN33M1GYySCj',
  'access_token': '52647948-xnlwpbETyFNX0JmEcdrsB7FLI42fTimAbyXK1xgOM',
  'access_token_secret': 'xiYL3QEpPmNmbR0AhqphvS2s2Tyf0V0FOOcpKRb92d4kL',
}
bon = botornot.BotOrNot(**twitter_app_auth)

# %%
df = pd.read_csv('training_data_2_csv_UTF.csv',encoding = "UTF")
df_test = pd.read_csv('test_data_4_students.csv',encoding='UTF')

# %%
df_curr = df
user_name=np.array(df_curr.screen_name)
is_bot = np.array(df_curr.bot)
user_name_small = user_name #[:30]
is_bot_small = is_bot #[:30]

# %% [markdown]
# ### 采集主程序

# %% [markdown]
# # No BotOrNot

# %%
with open('test_set_1.csv','w') as f:
    spamwriter = csv.writer(f)
    spamwriter.writerow(['index']+['id']+['id_str']+['screen_name']+['location']+['description']+['url']+['followers_count']+['friends_count']+
        ['listedcount']+['created_at']+['favourites_count']+['verified']+['statuses_count']+['lang']+['default_profile']+['default_profile_image']
        +['has_extended_profile']+['name']+['BotOrNot']+["content_classification"]+["friend_classification"] + ["network_classification"] + ["sentiment_classification"]+ ["temporal_classification"]+["user_classification"]+['status']+['bot'] )
    count = 0
    for i in user_name_small:
        count = count + 1
        i=i.strip('"')
        try:
            user=api.get_user(i)
        except:
            st=[count,-1,-1,i]
            spamwriter.writerow(st)
            continue

        st=[count,user.id,user.id_str,user.screen_name,user.location,user.description,user.url,user.followers_count,user.friends_count
        ,user.listed_count,user.created_at,user.favourites_count,user.verified,user.statuses_count,user.lang,user.default_profile,user.default_profile_image
        ,user.has_extended_profile,user.name]
        print (count)
        print (user.screen_name)
        try:
            user_status = user.status._json
        except:
            user_status = None
        else:
            st = st + [user_status]
        spamwriter.writerow(st)
#         time.sleep(0.5)
# Out:
# 1
# HoustonPokeMap
# 2
# kernyeahx
# 3
# mattlieberisbot
# 4
# sc_papers
# 5
# lucarivera16
# 6
# dantheimprover
# 7
# _all_of_us_
# 8
# KatamariItems
# 9
# AutophagyPapers
# 10
# HSC_papers
# 11
# everycheese
# 12
# gyr_papers
# 14
# AjstyleAlen
# 15
# Rupesh93505
# 16
# hard_to_yelp
# 17
# fuckeverywordza
# 18
# yeahTonyaGonzal
# 20
# ecin_gnihtaseod
# 21
# tofu_product
# 22
# onetruewiseman
# 23
# everycolorbot
# 24
# himawari8bot
# 25
# emoji__polls
# 26
# everytrolltroll
# 27
# hyphizer
# 28
# GreenwadeGema
# 29
# par_papers
# 30
# everyMTGlegend
# 31
# assembly_papers
# 32
# DeepDreamThis
# 33
# baron777111
# 34
# BestOpinionPoll
# 35
# dstroyeveryword
# 36
# 917_7513
# 37
# snowcloneminute
# 38
# NESGarbageBot
# 39
# BklynMuseumBot
# 40
# clitoscope
# 41
# feud_exe
# 42
# vaporfave
# 43
# peabero89
# 44
# UcOVJ4xlZaGwtKm
# 45
# moonmurmur
# 46
# AttentiveBot
# 47
# vocalsvt
# 48
# 249_4665
# 49
# Ttimmson74
# 50
# LondonPogoMap
# 51
# CrisprPhages
# 52
# forestgen
# 53
# phy_papers
# 54
# rnomics
# 55
# woloshinj_buzz
# 56
# DiGRAThemes
# 57
# Twisted_Maglion
# 58
# shantae_stubby
# 59
# super_jeopardy
# 60
# Speed_1994
# 61
# TheUniverse
# 62
# everywordNYT
# 63
# Exoriders
# 64
# onlymanthings
# 65
# maximotxx
# 66
# violajacobs2414
# 67
# Lake5Media
# 68
# crystalliser
# 69
# SeethingVortex
# 70
# Horse_ebooks
# 71
# FMKVote
# 72
# biorxiv_evobio
# 73
# BoazimBot
# 74
# ClipArtBot
# 75
# gotogyuterte
# 76
# libraryofvivec
# 77
# ItMeIRL
# 78
# Rober4628
# 79
# aura_mazon
# 80
# MBPoGoAlert
# 81
# tiny_star_field
# 82
# pentametron
# 83
# ArkhamSingles
# 84
# NYC_Newswire
# 85
# VegasPokeMap
# 86
# literaldevices
# 87
# emojicheer
# 88
# EuphemismBot
# 89
# NK_papers
# 90
# oliviataters
# 91
# QuantomBot
# 92
# zatieot
# 94
# FreeFlattery
# 95
# everyboolean
# 96
# bxv_molbiol
# 97
# ColBertStephens
# 98
# scillaria
# 99
# MoskowitzMooney
# 100
# threedesert
# 101
# IFClueBot
# 102
# dejiwall
# 103
# PokemonGONewsUS
# 104
# ManoelaBeta7
# 105
# TahoeChains
# 106
# Every3Minutes
# 107
# Anuroopjr
# 108
# ursulaflanagan
# 109
# jowueob20
# 110
# quitoehck27
# 111
# HAroldbtmeme28
# 112
# katharyns25
# 113
# hakusongs
# 114
# thewillthewisp
# 115
# living_newyork
# 116
# soamazingquote
# 117
# loriwcute
# 118
# trinityadam
# 119
# regurol1994
# 120
# Cardinal_Fang
# 121
# RACQUELW86
# 122
# plzrevisit
# 123
# dailymoist
# 124
# killcodes
# 125
# _emo_ji
# 126
# SadisticMedic_
# 127
# prix_fixe_exe
# 128
# evoldir
# 129
# _grammar_
# 130
# itsavailable
# 131
# everyletterbot
# 132
# PressXToBot
# 133
# julissaf93
# 134
# IFinspiration
# 135
# taehyungirl30
# 136
# MagicRealismBot
# 137
# EpicSGPokemon
# 138
# pops131
# 139
# ScottalenLeeRo1
# 140
# face_withface
# 141
# lvnt2000
# 142
# McdanielArmijo
# 143
# all_in_cards
# 144
# autocompletejok
# 145
# FalalalaBot
# 146
# msxs_2016
# 147
# harmonsway1013
# 148
# CTCF_Papers
# 149
# 2noob2btrue
# 150
# virus_genome
# 151
# fitzpatrickmen4
# 152
# MetaphorMagnet
# 153
# imtherealdontai
# 154
# everygothcolor
# 155
# lillyb121
# 156
# best_tv_recaps
# 157
# Nucleosome_Bot
# 158
# KathlenelTloi
# 159
# NArcisal20
# 160
# PentatonicBot
# 161
# biorxiv_micrbio
# 162
# crossword_regex
# 163
# think_i_do
# 164
# wowwwrude
# 165
# angrystepparent
# 166
# TavernOfMirth
# 167
# voasekuck87
# 168
# hihiCherylsC
# 169
# everywordcup
# 170
# tcellbiology
# 171
# JargonTron
# 172
# MuscleStemCell
# 173
# botechre
# 174
# sjuworkerr
# 175
# MIlissawhihix
# 176
# biorxiv_biophys
# 177
# Bedr0ckLearning
# 178
# AwfulEmoji
# 179
# twoemoji
# 180
# everynerd
# 181
# vuguiwi1991
# 182
# TumorImm_papers
# 183
# donalddrumpfbot
# 184
# janine_baradi
# 185
# attribot
# 186
# baaldraavers
# 187
# MOF_papers
# 189
# Anthonyswag18
# 190
# poll_test
# 191
# zorak_ebooks
# 192
# Bot_Nohomo
# 193
# JeseniaT16
# 194
# Kozzzy24
# 195
# riverlevel_1867
# 196
# re3makes
# 197
# SpellerBot
# 198
# BletchleyRoll
# 199
# fastsamueldwrig
# 200
# RootPapers
# 201
# weatherlies_bot
# 202
# Victoriaavell11
# 203
# DJ_EBOOKS
# 204
# Popgen_Papers
# 205
# AskAndAnswerBot
# 206
# jakeuip27
# 207
# tylerstacos_
# 208
# 2UvyAyaFb5jpLby
# 209
# Botgle
# 210
# hotelbotai
# 211
# TysonFosterz
# 212
# AutoVids
# 213
# ParrotFlaubert
# 214
# bidoof_bot
# 215
# butt_things
# 216
# moajaqind1982
# 217
# riuleew83
# 218
# preprints_metab
# 219
# valid9tion
# 220
# litts_mccarlie
# 221
# SunsetGenerator
# 222
# peawme
# 223
# Jacktheboss434
# 225
# buzarun
# 226
# DPLAbot
# 227
# i_akari_daisuki
# 228
# wowwwiftrue
# 229
# gloster_tilda
# 230
# buoypix
# 231
# MusicmakerBot
# 232
# erowidrecruiter
# 233
# TVCommentBot
# 234
# arXiv_grqc
# 235
# allnothings
# 236
# pkmn_bonsai
# 237
# memcached_magic
# 238
# elmerw28
# 239
# PriceOfDogecoin
# 240
# chicknolapowell
# 241
# meua_lee
# 242
# a_travel_bot
# 243
# MAmuamunt
# 244
# wordisaprison
# 245
# selfportraitexe
# 246
# TermsofSbot
# 247
# walenar21
# 248
# pseudo_papers
# 249
# lncRNA_papers
# 250
# Now_Boobs
# 251
# snailsnake
# 252
# duane_persaud
# 253
# ValentinoBot
# 254
# relations_js
# 255
# bandname_exe
# 256
# LoremipsumBot
# 257
# genie_nelson
# 258
# ManyJams
# 259
# Marquis_Turnerx
# 260
# katheyp27
# 261
# mozerablebot
# 262
# LitOffLanterns
# 263
# oiledits
# 264
# BeaHgiant
# 265
# GrantsBotGov
# 266
# mcgucket_bot
# 267
# BowieK66
# 268
# ducknoteprice
# 269
# robotrecipes
# 270
# everyumlaut
# 271
# glossatory
# 272
# Fancypants6047
# 273
# Hedgehogize
# 274
# jamieph93986621
# 275
# NothemDonella
# 276
# pony_strategies
# 277
# imgconvos
# 278
# StobbeKindra
# 279
# cgagraphics
# 280
# ngthaohuong97
# 281
# m_h_nishimura
# 282
# TheYearofLuigi
# 283
# litpatches_txt
# 284
# everysimile
# 285
# J_C_Christensen
# 286
# lenirvana666
# 287
# DrPhilRx
# 288
# DivinaCooperi
# 289
# libraryofemoji
# 290
# wrap_papers
# 291
# BloombrgNewsish
# 292
# OliverBarkBark
# 293
# jargotron
# 294
# Games4Grownups
# 295
# Lowpolybot
# 296
# 2blessed_exe
# 297
# poem_exe
# 298
# HigherEdSurge
# 299
# GUNNERCARTERXX
# 300
# myah581
# 301
# starnearyou
# 302
# wayback_exe
# 303
# wutahiq19
# 304
# OldLSystemBot
# 305
# low_battery_tho
# 306
# yeahashleyrober
# 307
# WonderWoman0716
# 308
# faq_walkthrough
# 309
# AutoNetflix
# 310
# FeinmanAltha
# 311
# VoynichTechNews
# 312
# xx5sosvines01
# 313
# throam_bot
# 314
# NMBPoGoAlert
# 315
# ButtlawMcButt
# 316
# GilgameshTweets
# 317
# dronesweetie
# 318
# PenryParmelee
# 319
# altagraciao86
# 320
# bookonbalcony
# 321
# SuperbOwl3000
# 322
# ARealRiver
# 323
# tiny_astro_naut
# 324
# ceubehen
# 325
# ljw269
# 327
# marcelinep16
# 328
# epigen_papers
# 329
# tardygram
# 330
# SharksOnCouches
# 331
# LucileRobertsa
# 332
# SylverBot
# 333
# adventvrecall
# 334
# greatartbot
# 335
# dtufreak
# 336
# patrinafbryantz
# 337
# bot_things
# 338
# MuzeumBot
# 339
# fantasy_florist
# 340
# hypoxiapapers
# 342
# netflixtaglines
# 343
# MythologyBot
# 344
# THMarcella
# 345
# themetgallery
# 346
# FFD8FFDB
# 347
# DuniaOnePiece
# 348
# wz77
# 349
# scell_papers
# 350
# WizardGenerator
# 351
# bouquetbot
# 352
# astronaut_bot
# 353
# censusAmericans
# 354
# tibbits_marcus
# 355
# 3461holley
# 356
# isu_bot2_fs
# 357
# HaikuMurakami
# 358
# Clippy_exe
# 359
# fullmetaliberty
# 360
# cancerSL
# 361
# phylogeo_papers
# 362
# asdfghjkl0l2
# 363
# sexyeveryword
# 364
# hortensiadicke3
# 365
# Sexkitten0422
# 366
# kanyejordan
# 367
# someboxes
# 368
# mahireyvazov
# 369
# mlegoudes262
# 370
# 1lovetakes2
# 371
# coolbot420
# 372
# topbiopapers
# 373
# STaafunnyx
# 374
# bionet_papers
# 375
# pizzaclones
# 376
# DistractedGenie
# 377
# space_stories
# 378
# CantorLogical
# 379
# sg_ebooks
# 380
# scientificpaper
# 381
# biorxiv_genomic
# 382
# scdicaprio
# 383
# allemptysets
# 384
# thedismalblog
# 385
# ahouseofdust
# 386
# NY_Now
# 387
# _LostBuoy_
# 388
# spear_one
# 389
# kordeidangerouz
# 390
# andrewhuangbot
# 391
# AllTheCheeses
# 392
# fly_papers
# 393
# Suarez06356267
# 394
# Eyescaler
# 395
# soeqaib
# 396
# AllOilPainting
# 397
# SmoothUnicode
# 398
# charand522
# 399
# CultEvoBot
# 400
# SAmallenxx18
# 401
# beiwiqe25
# 402
# helpmeetgoal
# 403
# chinesphere
# 404
# xbangtan1
# 405
# eachtown
# 406
# NixieBot
# 407
# Zzt_ebooks
# 408
# angelia_irr
# 409
# NaiveAnswers
# 410
# biofilmPapers
# 411
# baeksehuniie
# 412
# TwoHeadlines
# 413
# sponge_papers
# 414
# CitiBikeDocks
# 415
# likeuberbut
# 416
# beefl96
# 417
# GoogleFacts
# 418
# vox_ebooks
# 419
# synbio_papers
# 420
# nice_tips_bot
# 421
# quantifiedinky
# 422
# ididmorepushups
# 423
# assignments_txt
# 424
# TwitterMovies
# 425
# lixoxept96
# 426
# BotMtGFlavor
# 427
# DSWalsh6
# 428
# XsGonnaX
# 429
# Fact
# 430
# reverseocr
# 431
# anamariaq27
# 432
# litoraptor
# 433
# colorschemez
# 434
# startup_o_matic
# 435
# Joey_Cartero
# 436
# 1pRsHsia8WbmoD7
# 437
# menubot
# 438
# BioCodePapers
# 439
# gorillacities
# 440
# SydneyPogoMap
# 441
# JpTeixeira01
# 442
# CRISPR_papers
# 444
# suavkog95
# 447
# TrevisanOlympia
# 448
# ProtasMerrill
# 449
# not_a_cop_bot
# 451
# MltplSclppr
# 452
# theDesireBot
# 453
# VillanelleBot
# 454
# USPRI
# 455
# ideabot
# 456
# BadArtThief
# 457
# fuckingbard
# 458
# pixelsorter
# 459
# ThreeCourseMeal
# 460
# Keifer67684948
# 461
# artassignbot
# 462
# botsummittalks
# 463
# ZinaJ26
# 464
# zopuolond93
# 465
# eAgreeTeam
# 466
# EnjoyTheFilm
# 467
# _DJ_3000_
# 468
# sunsetonari
# 469
# infinitedeserts
# 470
# jonttxoxoa
# 471
# emojidreams
# 472
# CutePetsDenver
# 473
# porcadapalabra
# 474
# MelPogoMap
# 475
# SimGenerator
# 476
# suaj30
# 477
# YouAreCarrying
# 478
# Hollon1120
# 479
# zackeryssuperz
# 480
# RNAi_papers
# 481
# mrsfishsfunkys
# 482
# LilSpellbook
# 483
# theIntialCommit

# %%
with open('training_set_2.csv','w') as f:
    spamwriter = csv.writer(f)
    spamwriter.writerow(['index']+['id']+['id_str']+['screen_name']+['location']+['description']+['url']+['followers_count']+['friends_count']+
        ['listedcount']+['created_at']+['favourites_count']+['verified']+['statuses_count']+['lang']+['default_profile']+['default_profile_image']
        +['has_extended_profile']+['name']+['BotOrNot']+["content_classification"]+["friend_classification"] + ["network_classification"] + ["sentiment_classification"]+ ["temporal_classification"]+["user_classification"]+['status']+['bot'] )
    count = 0
    for i in user_name_small:
        count = count + 1
        i=i.strip('"')
        try:
            user=api.get_user(i)
        except:
            st=[count,-1,-1,i]
            spamwriter.writerow(st)
            continue
        try:
            result = bon.check_account(i) #BotOrNot判断程序 
            st=[count,user.id,user.id_str,user.screen_name,user.location,user.description,user.url,user.followers_count,user.friends_count
            ,user.listed_count,user.created_at,user.favourites_count,user.verified,user.statuses_count,user.lang,user.default_profile,user.default_profile_image
            ,user.has_extended_profile,user.name, result["score"],result["categories"]["content_classification"],result["categories"]["friend_classification"],result["categories"]["network_classification"],result["categories"]["sentiment_classification"],result["categories"]["temporal_classification"],result["categories"]["user_classification"]]
        except:
            st=[count,user.id,user.id_str,user.screen_name,user.location,user.description,user.url,user.followers_count,user.friends_count
            ,user.listed_count,user.created_at,user.favourites_count,user.verified,user.statuses_count,user.lang,user.default_profile,user.default_profile_image
            ,user.has_extended_profile,user.name, -1,-1,-1,-1,-1,-1,-1]
        print (count)
        print (user.screen_name)
        try:
            user_status = user.status._json
        except:
            user_status = None
        else:
            st = st + [user_status]+[is_bot_small[count-1]]
        spamwriter.writerow(st)
        time.sleep(0.5)
# Out:
# 1
# HoustonPokeMap
# 2
# kernyeahx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-77d7a5cf7249> in <module>()
#      32             st = st + [user_status]+[is_bot_small[count-1]]
#      33         spamwriter.writerow(st)
# ---> 34         time.sleep(0.5)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Re-generate data by id

# %%
with open('bots1.csv','w') as f:
	spamwriter = csv.writer(f)
	spamwriter.writerow(['id']+['id_str']+['screen_name']+['location']+['description']+['url']+['followers_count']+['friends_count']+
		['listedcount']+['created_at']+['favourites_count']+['verified']+['statuses_count']+['lang']+['default_profile']+['default_profile_image']
		+['has_extended_profile']+['name']+['status'])
	for i in user_name_small:
		try:
			user=api.get_user(i)
		except:
			continue
		st=[user.id,user.id_str,user.screen_name,user.location,user.description,user.url,user.followers_count,user.friends_count
		,user.listed_count,user.created_at,user.favourites_count,user.verified,user.statuses_count,user.lang,user.default_profile,user.default_profile_image
		,user.has_extended_profile,user.name]
		print (user.screen_name)
		try:
			user_status = user.status
		except:
			user_status = None
		else:
			st = st + [user_status]
		spamwriter.writerow(st)

# %%
user=api.get_user(200694438)
print (user.screen_name)
# Out:
# _mayf

# %%
user=api.get_user('_mayf')
print (user.id)
# Out:
# 200694438

# %%
result = bon.check_account('CointraqBot') #BotOrNot判断程序
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-35-845118f4e9c1> in <module>()
# ----> 1 result = bon.check_account('CointraqBot') #BotOrNot判断程序
#
# /Users/alvin/anaconda3/lib/python3.5/site-packages/botornot/__init__.py in check_account(self, user)
#     118
#     119     def check_account(self, user):
# --> 120         user_data, tweets = self._get_user_and_tweets(user)
#     121         if not tweets:
#     122             raise NoTimelineError(user)
#
# /Users/alvin/anaconda3/lib/python3.5/site-packages/botornot/__init__.py in _get_user_and_tweets(self, user)
#      94         except RateLimitError as e:
#      95             e.args = (self._TWITTER_RL_MSG, 'search/tweets')
# ---> 96             raise e
#      97
#      98         tweets = user_timeline + search['statuses']
#
# /Users/alvin/anaconda3/lib/python3.5/site-packages/botornot/__init__.py in _get_user_and_tweets(self, user)
#      91
#      92         try:
# ---> 93             search = self.twitter_api.search(screen_name, count=100)
#      94         except RateLimitError as e:
#      95             e.args = (self._TWITTER_RL_MSG, 'search/tweets')
#
# /Users/alvin/anaconda3/lib/python3.5/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /Users/alvin/anaconda3/lib/python3.5/site-packages/tweepy/binder.py in execute(self)
#     225
#     226                 if is_rate_limit_error_message(error_msg):
# --> 227                     raise RateLimitError(error_msg, resp)
#     228                 else:
#     229                     raise TweepError(error_msg, resp, api_code=api_error_code)
#
# RateLimitError: [{'code': 88, 'message': 'Rate limit exceeded'}]

# %%
result["score"]
# Out:
# 0.28

# %% [markdown]
# # BackUp

# %%
user=api.get_user("HoustonPokeMap")
user_status = user.status
print(user_status)

temp = df.status[:10]
for i in df.status:
    print (len(i._json))


#print(df_old.head(5))
df.status[2]
json_str = json.dumps(user_status._json)
print(json_str)


user_status._json['lang']
for ii in user_status._json:
    print(ii)
    print(user_status._json[ii])

len(user_status._json)
