# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('bots_data.csv',encoding = "ISO-8859-1")
df2 = pd.read_csv('nonbots_data.csv',encoding = "ISO-8859-1")
print(df1.shape)
print(df2.shape)
df1.head(13)
# Out:
# (1056, 20)
# (1176, 20)
#               id      id_str      screen_name       location  \
# 0   3.982732e+09  3982731976     mcgucket_bot            NaN
# 1   8.410000e+17    8.41E+17         BowieK66            NaN
# 2   2.768375e+09  2768374981    ducknoteprice            NaN
# 3   3.304189e+09  3304189373     robotrecipes  robot kitchen
# 4   3.224289e+09  3224289024      everyumlaut            NaN
# 5   7.300000e+17    7.30E+17       glossatory      Australah
# 6   8.200000e+17    8.20E+17   Fancypants6047      vancouver
# 7   2.602217e+09  2602217174      Hedgehogize        Moebius
# 8   8.330000e+17    8.33E+17  jamieph93986621            NaN
# 9   8.250000e+17    8.25E+17    NothemDonella            NaN
# 10  2.215074e+09  2215073972  pony_strategies            NaN
# 11  2.903086e+09  2903085721        imgconvos            NaN
# 12  8.270000e+17    8.27E+17     StobbeKindra            NaN
#
#                                           description  \
# ...

# %%
xstr = 'followers_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['followers_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['followers_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'listedcount'
x = np.array(df1.index)
y = np.log10(np.array(df1['listedcount']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['listedcount']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'favourites_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['favourites_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['favourites_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'favourites_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['favourites_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['favourites_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'statuses_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['statuses_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['statuses_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
sname = np.array(df1.screen_name)
sname
# Out:
# array(['mcgucket_bot', 'BowieK66', 'ducknoteprice', ..., 'moltar_ebooks',
#        'DCell_papers', 'A20989664A'], dtype=object)

# %%
f = lambda i: len(sname[i])
np.fromfunction(np.vectorize(f), (len(sname), ), dtype=int)
# Out:
# array([12,  8, 13, ..., 13, 12, 10])

# %%
g = lambda i: len(i)
gg = np.vectorize(g)
gg(sname)
# Out:
# array([12,  8, 13, ..., 13, 12, 10])

# %%
location = np.array(df1.location)

# %%
def h(x):
    if (type(x) == type('str')) :
        return 1
    else:
        return 0

# %%
hh = np.vectorize(h)
hh(location)
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
status = np.array(df1.status)
status
type(status[0])
# Out:
# str

# %%
df1.head(10)
# Out:
#              id      id_str      screen_name       location  \
# 0  3.982732e+09  3982731976     mcgucket_bot            NaN
# 1  8.410000e+17    8.41E+17         BowieK66            NaN
# 2  2.768375e+09  2768374981    ducknoteprice            NaN
# 3  3.304189e+09  3304189373     robotrecipes  robot kitchen
# 4  3.224289e+09  3224289024      everyumlaut            NaN
# 5  7.300000e+17    7.30E+17       glossatory      Australah
# 6  8.200000e+17    8.20E+17   Fancypants6047      vancouver
# 7  2.602217e+09  2602217174      Hedgehogize        Moebius
# 8  8.330000e+17    8.33E+17  jamieph93986621            NaN
# 9  8.250000e+17    8.25E+17    NothemDonella            NaN
#
#                                          description                      url  \
# 0  A bot that tweets every line said by Fiddlefor...                      NaN
# 1                                                NaN                      NaN
# ...

# %%
df_10 = df1.head(10)

# %%
df10_sorted = df_10.sort_values('listedcount',na_position='first')

# %%
df10_sorted
# Out:
#              id      id_str      screen_name       location  \
# 1  8.410000e+17    8.41E+17         BowieK66            NaN
# 6  8.200000e+17    8.20E+17   Fancypants6047      vancouver
# 8  8.330000e+17    8.33E+17  jamieph93986621            NaN
# 0  3.982732e+09  3982731976     mcgucket_bot            NaN
# 2  2.768375e+09  2768374981    ducknoteprice            NaN
# 5  7.300000e+17    7.30E+17       glossatory      Australah
# 9  8.250000e+17    8.25E+17    NothemDonella            NaN
# 4  3.224289e+09  3224289024      everyumlaut            NaN
# 7  2.602217e+09  2602217174      Hedgehogize        Moebius
# 3  3.304189e+09  3304189373     robotrecipes  robot kitchen
#
#                                          description                      url  \
# 1                                                NaN                      NaN
# 6                                                NaN                      NaN
# ...

# %%
df10_sorted.iloc[0:5]
# Out:
#              id      id_str      screen_name   location  \
# 1  8.410000e+17    8.41E+17         BowieK66        NaN
# 6  8.200000e+17    8.20E+17   Fancypants6047  vancouver
# 8  8.330000e+17    8.33E+17  jamieph93986621        NaN
# 0  3.982732e+09  3982731976     mcgucket_bot        NaN
# 2  2.768375e+09  2768374981    ducknoteprice        NaN
#
#                                          description  url  followers_count  \
# 1                                                NaN  NaN                0
# 6                                                NaN  NaN               41
# 8          I wasn't bor ysterday,  was born tomorrow  NaN                0
# 0  A bot that tweets every line said by Fiddlefor...  NaN             1129
# 2                                                NaN  NaN                3
#
#    friends_count  listedcount                      created_at  \
# 1             22            0                13/03/2017 22:21
# ...

# %% [markdown]
# # BackUp

# %%
import numpy as np 

x = np.array([1, 2, 3, 4, 5])

# Obtain array of square of each element in x
squarer = lambda t: t ** 2
#option 1

# %% [markdown]
# ###### option 1

# %%
vfunc = np.vectorize(squarer)
vfunc(x) #速度更快
# Out:
# array([ 1,  4,  9, 16, 25])

# %% [markdown]
# ##### option 2

# %%
squarer(x)
# Out:
# array([ 1,  4,  9, 16, 25])

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)

# %%
xstr = 'friends_count'
x = np.array(df1.index)
y = np.log10(np.array(df1['friends_count']))
x1 = np.array(df2.index)
y1 = np.log10(np.array(df2['friends_count']))
plt.plot(x,y,'.',x1,y1,'.')
plt.grid(True)
