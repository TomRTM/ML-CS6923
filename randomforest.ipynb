# %%
from sklearn import tree
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

df = pd.read_csv('training_data_2_csv_UTF.csv',encoding = "ISO-8859-1")
df.head(4)
# Out:
#              id                id_str       screen_name  \
# 0  8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1  4.843621e+09            4843621225         kernyeahx
# 2  4.303727e+09            4303727112   mattlieberisbot
# 3  3.063139e+09            3063139353         sc_papers
#
#                     location  \
# 0              "Houston, TX"
# 1  Templeville town, MD, USA
# 2                        NaN
# 3                        NaN
#
#                                          description  \
# 0  "Rare and strong PokÅ½mon in Houston, TX. See ...
# 1  From late 2014 Socium Marketplace will make sh...
# 2  Inspired by the smart, funny folks at @replyal...
# 3                                                NaN
#
#                          url  followers_count  friends_count  listedcount  \
# 0  "https://t.co/dnWuDbFRkt"             1291              0           10
# 1                        NaN                1            349            0
# ...

# %%
j=0
for i in df.index:    
        if 'bot' in str(df.loc[i,'description'])or 'Bot' in str(df.loc[i,'description']) or 'b0t' in str(df.loc[i,'description']) or 'BOT' in str(df.loc[i,'description']) or 'B0T' in str(df.loc[i,'description']) or 'boT' in str(df.loc[i,'description']):
            
            df.loc[i,'flag1'] = True
            j=j+1
        else:
            df.loc[i,'flag1'] = False
print(j)
# Out:
# 409

# %%
j=0
for i in df.index:    
        if 'bot' in str(df.loc[i,'screen_name'])or 'Bot' in str(df.loc[i,'screen_name']) or 'b0t' in str(df.loc[i,'screen_name']) or 'BOT' in str(df.loc[i,'screen_name']) or 'B0T' in str(df.loc[i,'screen_name']) or 'boT' in str(df.loc[i,'screen_name']):
            
            df.loc[i,'flag2'] = True
            j=j+1
        else:
            df.loc[i,'flag2'] = False
print(j)
# Out:
# 232

# %%
j=0
for i in df.index:    
        if 'bot' in str(df.loc[i,'name'])or 'Bot' in str(df.loc[i,'name']) or 'b0t' in str(df.loc[i,'name']) or 'BOT' in str(df.loc[i,'name']) or 'B0T' in str(df.loc[i,'name']) or 'boT' in str(df.loc[i,'name']):
            
            df.loc[i,'flag3'] = True
            j=j+1
        else:
            df.loc[i,'flag3'] = False
print(j)
# Out:
# 198

# %%
df.head(5)
# Out:
#              id                id_str       screen_name  \
# 0  8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1  4.843621e+09            4843621225         kernyeahx
# 2  4.303727e+09            4303727112   mattlieberisbot
# 3  3.063139e+09            3063139353         sc_papers
# 4  2.955142e+09            2955142070      lucarivera16
#
#                     location  \
# 0              "Houston, TX"
# 1  Templeville town, MD, USA
# 2                        NaN
# 3                        NaN
# 4      Dublin, United States
#
#                                          description  \
# 0  "Rare and strong PokÅ½mon in Houston, TX. See ...
# 1  From late 2014 Socium Marketplace will make sh...
# 2  Inspired by the smart, funny folks at @replyal...
# 3                                                NaN
# 4             Inspiring cooks everywhere since 1956.
#
#                          url  followers_count  friends_count  listedcount  \
# ...

# %%
# df['has_extended_profile']=df['has_extended_profile'].fillna(False)
# df['default_profile_image']=df['default_profile_image'].fillna(False)

# %%
features = [df.columns[6],df.columns[7],df.columns[12],df.columns[20],df.columns[21],df.columns[22]]
def test1():
    df['is_train'] = np.random.uniform(0, 1, len(df)) <= .75
    train, test = df[df['is_train']==True], df[df['is_train']==False]
    #print('Number of observations in the training data:', len(train))
    #print('Number of observations in the test data:',len(test))
    y=train['bot']
    clf = RandomForestClassifier(n_jobs=2)
    clf.fit(train[features], y)
    pred=clf.predict(test[features])
    return (np.mean(pred==test['bot']))

# %%
sum(test1() for _ in range(10))/10.0
# Out:
# 0.87921584534503094

# %%
df['is_train'] = np.random.uniform(0, 1, len(df)) <= .75
train, test = df[df['is_train']==True], df[df['is_train']==False]
# print('Number of observations in the training data:', len(train))
# print('Number of observations in the test data:',len(test))

# %%
features = [df.columns[6],df.columns[7],df.columns[11],df.columns[12],df.columns[20],df.columns[21],df.columns[22]]

features
# Out:
# ['followers_count',
#  'friends_count',
#  'verified',
#  'statuses_count',
#  'flag1',
#  'flag2',
#  'flag3']

# %%
y=train['bot']

# %%
clf = RandomForestClassifier(n_jobs=2)
clf.fit(train[features], y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=2, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
pred=clf.predict(test[features])
print (np.mean(pred==test['bot']))
# Out:
# 0.964673913043

# %%
# clf.predict_proba(test[features])

# %%
list(zip(train[features], clf.feature_importances_))
# Out:
# [('followers_count', 0.25670853050943554),
#  ('friends_count', 0.3664394591003215),
#  ('verified', 0.1209383980011173),
#  ('statuses_count', 0.14882579955097711),
#  ('flag1', 0.077340235851785372),
#  ('flag2', 0.017076945580206011),
#  ('flag3', 0.012670631406157132)]

# %%
# Out:
# numpy.bool_

# %%
# features_tree=[df.columns[6],df.columns[7],df.columns[10],df.columns[12],df.columns[11],df.columns[15],df.columns[16]]
# features_tree
# clftree = tree.DecisionTreeClassifier()
# clftree = clftree.fit(train[features_tree], y)
# clftree.predict(test[features_tree])
# predtree=clftree.predict(test[features_tree])
# print (np.mean(predtree==test['bot']))

# %%
# print(len(test))
# j=0
# changed =0
# for i in test['screen_name']:
#     if 'bot' in i or 'Bot' in i or 'b0t' in i or 'BOT' in i:
#         if pred[j]!=1:
#             pred[j]=1
            
#             print(j)
#             changed=changed+1
#         j=j+1
# print (np.mean(pred==test['bot']))
# print(changed)
# print(type(pred[1]))
# Out:
# 790
# 21
# 23
# 24
# 25
# 50
# 53
# 54
# 59
# 0.912658227848
# 8
# <class 'numpy.int64'>

# %%
# print(len(test))
# j=0
# changed =0
# for i in test['description']:
#      if 'bot' in str(i) or 'Bot' in str(i) or 'b0t' in str(i):
#         if pred[j]!=1:
#             pred[j]=1
            
#             print(j)
#             changed=changed+1
#         j=j+1
# print (np.mean(pred==test['bot']))
# print(changed)
# Out:
# 790
# 68
# 84
# 90
# 0.916455696203
# 3

# %%
# j=0
# for i in test['description']: 
#     if type(i)==float:
#         i=str(i)
#     #print(pred[j])
#     #print(type(i))
#     j=j+1

# %%
# df['default_profile'].describe()

# %%
df_test = pd.read_csv('test_data_4_students.csv',encoding = "UTF").dropna(how='all')
df_test.head(20)
# Out:
#               id      id_str      screen_name            location  \
# 0   2.281293e+09  2281292622        __keating            brooklyn
# 1   2.344040e+09  2344040251     _callme_Dani     Los Angeles, CA
# 2   7.658713e+08   765871267   _little_britt_                 NaN
# 3   4.772373e+09  4772373433            134k5                 NaN
# 4   1.324549e+09        None    2181chrom_bot     è‡ªåˆ†ã®å¤©å¹•
# 5   2.561342e+09        None        2LA1R_bot                None
# 6   3.478101e+08        None         3pei_bot           ä¸‰æ²³å±‹
# 7   8.563039e+08        None      94kichi_bot                None
# 8   8.328750e+17        None  A3_Dekasegi_bot  ãƒ“ãƒ­ãƒ¼ãƒ‰é§…å‰
# 9   8.885679e+07        None       aamir_khan              Mumbai
# 10  7.135570e+17    7.14E+17  AceWallpaperBot                 NaN
# 11  1.566747e+09  1566746503    acormier_bzfd        New York, NY
# 12  9.042031e+07        None      ActuallyNPH       Manhattanland
# ...

# %%
df_test['id'][539]
# Out:
# 7.28e+17

# %%
newf=['followers_count',
 'friends_count',
      "verified",
 'statuses_count',
      
     'flag1','flag2'
      
     ,'flag3']

# %%
# def change(x):
#     if 'None' in x:
#         return median(x)
#     else:
#         return x
# df_test['listed_count']=df_test['listed_count'].map(change)
# df_test['favorites_count']=df_test['favorites_count'].map(change)
# #df_test['statuses_count']=df_test['statuses_count'].map(change)
# df_test['followers_count']=df_test['followers_count'].map(change)
# df_test['friends_count']=df_test['friends_count'].map(change)

# %%
# df_test['listed_count'] = pd.to_numeric(df_test['listed_count'],errors='coerce')

# df_test['listed_count'] = df_test['listed_count'].fillna(df_test['listed_count'].median())

# %%
# df_test['favorites_count'] = pd.to_numeric(df_test['favorites_count'],errors='coerce')

# df_test['favorites_count'] = df_test['favorites_count'].fillna(df_test['favorites_count'].median())

# %%
df_test['followers_count'] = pd.to_numeric(df_test['followers_count'],errors='coerce')

df_test['followers_count'] = df_test['followers_count'].fillna(df_test['followers_count'].median())

# %%
df_test['statuses_count'] = pd.to_numeric(df_test['statuses_count'],errors='coerce')

df_test['statuses_count'] = df_test['statuses_count'].fillna(df_test['statuses_count'].median())

# %%
df_test['friends_count'] = pd.to_numeric(df_test['friends_count'],errors='coerce')

df_test['friends_count'] = df_test['friends_count'].fillna(df_test['friends_count'].median())

# %%
df_test['verified']=df_test['verified'].replace("None", False)
df_test['verified']=df_test['verified'].replace("FALSE", False)
df_test['verified']=df_test['verified'].replace("TRUE", True)
# df_test['default_profile']=df_test['default_profile'].replace("None",False)
# df_test['default_profile']=df_test['default_profile'].replace("FALSE", False)
# df_test['default_profile']=df_test['default_profile'].replace("TRUE", True)

# %%
df_test['verified'].describe()
# Out:
# count       575
# unique        2
# top       False
# freq        372
# Name: verified, dtype: object

# %%
df_test['default_profile_image']=df_test['default_profile_image'].replace("None",False)
df_test['default_profile_image']=df_test['default_profile_image'].replace("FALSE", False)
df_test['default_profile_image']=df_test['default_profile_image'].replace("TRUE", True)

# %%
df_test['has_extended_profile']=df_test['has_extended_profile'].replace("None",False)
df_test['has_extended_profile']=df_test['has_extended_profile'].replace("FALSE", False)
df_test['has_extended_profile']=df_test['has_extended_profile'].replace("TRUE", True)

# %%
df_test.head(10)
# Out:
#    index                  id              id_str      screen_name  \
# 0      1          2281292622          2281292622        __keating
# 1      2          2344040251          2344040251     _callme_Dani
# 2      3           765871267           765871267   _little_britt_
# 3      4          4772373433          4772373433            134k5
# 4      5          1324548560          1324548560    2181chrom_bot
# 5      6          2561341789          2561341789        2LA1R_bot
# 6      7           347810134           347810134         3pei_bot
# 7      8           856303860           856303860      94kichi_bot
# 8      9  832874807754502144  832874807754502144  A3_Dekasegi_bot
# 9     10            88856792            88856792       aamir_khan
#
#           location                                        description  \
# 0         brooklyn  lgbt editor at @buzzfeed. shannon.keating@buzz...
# 1  Los Angeles, CA  News Curation Editor @BuzzFeedNews \nI do a lo...
# ...

# %%
j=0
for i in df_test.index:    
        if 'bot' in str(df_test.loc[i,'description'])or 'Bot' in str(df_test.loc[i,'description']) or 'b0t' in str(df_test.loc[i,'description']) or 'BOT' in str(df_test.loc[i,'description']) or 'B0T' in str(df_test.loc[i,'description']) or 'boT' in str(df_test.loc[i,'description']):
            #if str(df_test.loc[i,'lang'])=="en":
                df_test.loc[i,'flag1'] = True
                j=j+1
        else:
            df_test.loc[i,'flag1'] = False
print(j)
# Out:
# 183

# %%
j=0
for i in df_test.index:    
        if 'bot' in str(df_test.loc[i,'screen_name'])or 'Bot' in str(df_test.loc[i,'screen_name']) or 'b0t' in str(df_test.loc[i,'screen_name']) or 'BOT' in str(df_test.loc[i,'screen_name']) or 'B0T' in str(df_test.loc[i,'screen_name']) or 'boT' in str(df_test.loc[i,'screen_name']):
            
            df_test.loc[i,'flag2'] = True
            j=j+1
        else:
            df_test.loc[i,'flag2'] = False
print(j)
# Out:
# 207

# %%
j=0
for i in df_test.index:    
        if 'bot' in str(df_test.loc[i,'name'])or 'Bot' in str(df_test.loc[i,'name']) or 'b0t' in str(df_test.loc[i,'name']) or 'BOT' in str(df_test.loc[i,'name']) or 'B0T' in str(df_test.loc[i,'name']) or 'boT' in str(df_test.loc[i,'name']):
            
            df_test.loc[i,'flag3'] = True
            j=j+1
        else:
            df_test.loc[i,'flag3'] = False
print(j)
# Out:
# 159

# %%
clf = RandomForestClassifier(n_jobs=2)
clf.fit(df[features], df['bot'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=2, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
df_test.head(20)
# Out:
#     index                  id              id_str      screen_name  \
# 0       1          2281292622          2281292622        __keating
# 1       2          2344040251          2344040251     _callme_Dani
# 2       3           765871267           765871267   _little_britt_
# 3       4          4772373433          4772373433            134k5
# 4       5          1324548560          1324548560    2181chrom_bot
# 5       6          2561341789          2561341789        2LA1R_bot
# 6       7           347810134           347810134         3pei_bot
# 7       8           856303860           856303860      94kichi_bot
# 8       9  832874807754502144  832874807754502144  A3_Dekasegi_bot
# 9      10            88856792            88856792       aamir_khan
# 10     11  713556609784479744  713556609784479744  AceWallpaperBot
# 11     12          1566746503          1566746503    acormier_bzfd
# 12     13            90420314            90420314      ActuallyNPH
# ...

# %%
result=pd.DataFrame(df_test['id'])
result.insert(1,'bot',0)
rfresult=clf.predict(df_test[newf])

result['bot']=rfresult
result=result.astype(int)
pd.DataFrame(result).to_csv('result12.csv',sep=',',index=False)

# %%
# print(len(df_test))
# j=0
# changed =0
# for i in df_test['description']:
#      if 'bot' in str(i) or 'Bot' in str(i) or 'b0t' in str(i):
#         if rfresult[j]!=1:
#             rfresult[j]=1
#             print(j)
#             print(i)
#             print('********************')
#             changed=changed+1
#     j=j+1
# #print (np.mean(rfresult==test['bot']))
# print(changed)

# %%
# j=0
# changed =0
# for i in df_test['screen_name']:
#     if 'bot' in i or 'Bot' in i or 'b0t' in i or 'BOT' in i:
#         if rfresult[j]!=1:
#             rfresult[j]=1
            
#             print(j)
#             changed=changed+1
#     j=j+1
# #print (np.mean(pred==test['bot']))
# print(changed)
